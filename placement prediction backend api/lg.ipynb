# %%
import pandas as pd
df = pd.read_csv("D:\Placement Prediction Projects\placement_dataSet.csv")

df.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  projectsCount  PlacedOrNot
# 0                  1              2            1
# 1                  1              3            1
# 2                  0              4            1
# 3                  1              3            1
# 4                  0              3            1

# %%
df.shape
# Out:
# (2966, 9)

# %%
df['Gender'].replace({'Male':0, 'Female':1}, inplace=True)
# Out:
# C:\Users\91878\AppData\Local\Temp\ipykernel_5584\3683457849.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({'Male':0, 'Female':1}, inplace=True)
# C:\Users\91878\AppData\Local\Temp\ipykernel_5584\3683457849.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22       0  Electronics And Communication            1     8       1
# 1   21       1               Computer Science            0     7       1
# 2   22       1         Information Technology            1     6       0
# 3   21       0         Information Technology            0     8       0
# 4   22       0                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  projectsCount  PlacedOrNot
# 0                  1              2            1
# 1                  1              3            1
# 2                  0              4            1
# 3                  1              3            1
# 4                  0              3            1

# %%
df['Stream'].unique()
# Out:
# array(['Electronics And Communication', 'Computer Science',
#        'Information Technology', 'Mechanical', 'Electrical', 'Civil'],
#       dtype=object)

# %%
df['Stream'].replace({
    'Computer Science':0,
    'Information Technology':1,
    'Electronics And Communication':2,
    'Mechanical':3,
    'Electrical': 4,
    'Civil': 5
},inplace=True)

df.head()
# Out:
# C:\Users\91878\AppData\Local\Temp\ipykernel_5584\1555846577.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Stream'].replace({
# C:\Users\91878\AppData\Local\Temp\ipykernel_5584\1555846577.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Stream'].replace({
# ...

# %%
df.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Stream               0
# Internships          0
# CGPA                 0
# Hostel               0
# HistoryOfBacklogs    0
# projectsCount        0
# PlacedOrNot          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
stream = df['Stream']
age = df['Age']
gender = df['Gender']
ineternships = df['Internships']
cgpa = df['CGPA']
backlogs = df['HistoryOfBacklogs']
projects = df['projectsCount']
hostel = df['Hostel']

y = df['PlacedOrNot']

# %%
Y = df['PlacedOrNot']
X = df.drop(['PlacedOrNot'], axis=1)

# %%
X
# Out:
#       Age  Gender  Stream  Internships  CGPA  Hostel  HistoryOfBacklogs  \
# 0      22       0       2            1     8       1                  1
# 1      21       1       0            0     7       1                  1
# 2      22       1       1            1     6       0                  0
# 3      21       0       1            0     8       0                  1
# 4      22       0       3            0     8       1                  0
# ...   ...     ...     ...          ...   ...     ...                ...
# 2961   23       0       1            0     7       0                  0
# 2962   23       0       3            1     7       1                  0
# 2963   22       0       1            1     7       0                  0
# 2964   22       0       0            1     7       0                  0
# 2965   23       0       5            0     8       0                  0
#
#       projectsCount
# 0                 2
# 1                 3
# 2                 4
# ...

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2961    0
# 2962    0
# 2963    0
# 2964    0
# 2965    1
# Name: PlacedOrNot, Length: 2966, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
X_train
# Out:
#       Age  Gender  Stream  Internships  CGPA  Hostel  HistoryOfBacklogs  \
# 1191   22       0       2            1     7       1                  1
# 188    22       1       2            1     5       1                  0
# 1455   21       0       0            1     6       0                  0
# 2439   22       0       3            0     8       0                  0
# 2065   21       0       1            2     7       0                  1
# ...   ...     ...     ...          ...   ...     ...                ...
# 1301   26       0       4            0     7       1                  0
# 621    22       0       4            2     6       0                  0
# 1369   22       0       1            0     7       0                  0
# 305    22       0       0            0     6       0                  1
# 1004   22       0       4            2     6       0                  0
#
#       projectsCount
# 1191              4
# 188               3
# 1455              3
# ...

# %%
Y_train
# Out:
# 1191    0
# 188     0
# 1455    0
# 2439    1
# 2065    0
#        ..
# 1301    0
# 621     1
# 1369    0
# 305     0
# 1004    1
# Name: PlacedOrNot, Length: 2372, dtype: int64

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, r2_score

r2Score = r2_score(Y_test,predictions)
acc_score = accuracy_score(Y_test,predictions)

# print("R2 Score :",r2Score)
print("Accuracy  : ", acc_score*100,"%")
# Out:
# Accuracy  :  82.49158249158249 %

# %%
import pickle

# filename = 'plcpredLogReg.sav'

# pickle.dump(model, open(filename, 'wb'))

# %%
pickle_out = open("placpredModelLG.pkl",'wb')

pickle.dump(model, pickle_out)
pickle_out.close()

# %%
LG = open("placpredModelLG.pkl", 'rb')
LGmodel = pickle.load(LG)

A = (LGmodel.predict([[26,0,0,0,6,1,1,4]]))[0]
print((A))
# Out:
# 1
# d:\Placement Prediction Projects\plcpred\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
